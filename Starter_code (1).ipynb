# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(["EIN","NAME","INCOME_AMT"], axis=1, inplace=True)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS SPECIAL_CONSIDERATIONS   ASK_AMT  IS_SUCCESSFUL
# 0       Association       1                      N      5000              1
# 1      Co-operative       1                      N    108590              1
# 2       Association       1                      N      5000              0
# 3             Trust       1                      N      6692              1
# 4             Trust       1                      N    142590              1
# ...             ...     ...                    ...       ...            ...
# 34294   Association       1                      N      5000              0
# 34295   Association       1                      N      5000              0
# 34296   Association       1                      N      5000              0
# 34297   Association       1                      N      5000              1
# 34298  Co-operative       1                      N  36500179              0
#
# [34299 rows x 9 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
app_count = application_df['APPLICATION_TYPE'].copy()
app_count = app_count.value_counts()
application_index = app_count[(app_count < 528)].copy()
application_types_to_replace = application_index.index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
#application_types_to_replace
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
#use .info() method to have a descriptive look at the data
#Pandas uses the object data type to indicate categorical variables/columns

application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   APPLICATION_TYPE        34299 non-null  object
#  1   AFFILIATION             34299 non-null  object
#  2   CLASSIFICATION          34299 non-null  object
#  3   USE_CASE                34299 non-null  object
#  4   ORGANIZATION            34299 non-null  object
#  5   STATUS                  34299 non-null  int64
#  6   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  7   ASK_AMT                 34299 non-null  int64
#  8   IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 2.4+ MB

# %%
application_cat = application_df.dtypes[application_df.dtypes== "object"].index.to_list()

# %%
# Look at CLASSIFICATION value counts for binning
class_classification= application_df['CLASSIFICATION'].value_counts()
class_classification
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_classification[class_classification>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

class_index =class_classification[(class_classification < 1883)].copy()
classifications_to_replace = class_index.index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummies = pd.get_dummies(application_df)
application_dummies
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        USE_CASE_Heathcare  USE_CASE_Other  USE_CASE_Preservation  \
# 0                       0               0                      0
# 1                       0               0                      1
# 2                       0               0                      0
# 3                       0               0                      1
# 4                       1               0                      0
# ...                   ...             ...                    ...
# 34294                   0               0                      0
# 34295                   0               0                      0
# 34296                   0               0                      1
# 34297                   0               0                      0
# 34298                   0               0                      1
#
#        USE_CASE_ProductDev  ORGANIZATION_Association  \
# 0                        1                         1
# 1                        0                         0
# 2                        1                         1
# 3                        0                         0
# 4                        0                         0
# ...                    ...                       ...
# 34294                    1                         1
# 34295                    1                         1
# 34296                    0                         1
# 34297                    1                         1
# 34298                    0                         0
#
#        ORGANIZATION_Co-operative  ORGANIZATION_Corporation  \
# 0                              0                         0
# 1                              1                         0
# 2                              0                         0
# 3                              0                         0
# 4                              0                         0
# ...                          ...                       ...
# 34294                          0                         0
# 34295                          0                         0
# 34296                          0                         0
# 34297                          0                         0
# 34298                          1                         0
#
#        ORGANIZATION_Trust  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                       0                         1                         0
# 1                       0                         1                         0
# 2                       0                         1                         0
# 3                       1                         1                         0
# 4                       1                         1                         0
# ...                   ...                       ...                       ...
# 34294                   0                         1                         0
# 34295                   0                         1                         0
# 34296                   0                         1                         0
# 34297                   0                         1                         0
# 34298                   0                         1                         0
#
# [34299 rows x 35 columns]

# %%
# Split our preprocessed data into our features and target arrays
# Split our preprocessed data into our features and target arrays
y = application_dummies["IS_SUCCESSFUL"].values
X = application_dummies.drop(["IS_SUCCESSFUL","SPECIAL_CONSIDERATIONS_N"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# CREATE CHECK-POINT

# %%
# Import checkpoint dependencies
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every 5 epochs
cp_callback = ModelCheckpoint(filepath=checkpoint_path,
                              verbose=1,
                              save_weights_only=True,
                              save_freq='epoch',
                              period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ## Compile, Train and Evaluate the first Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 45

nn=tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1,
                             input_dim=number_input_features,
                             activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2,
                             activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1,
                             activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 80)                2720
#
#  dense_8 (Dense)             (None, 45)                3645
#
#  dense_9 (Dense)             (None, 1)                 46
#
# =================================================================
# Total params: 6,411
# Trainable params: 6,411
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy",
           optimizer="adam",
           metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,
                   y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5748 - accuracy: 0.7201
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5654 - accuracy: 0.7237
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5633 - accuracy: 0.7258
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5613 - accuracy: 0.7263
# Epoch 5/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5600 - accuracy: 0.7268
# Epoch 5: saving model to checkpoints/weights.05.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5600 - accuracy: 0.7268
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5596 - accuracy: 0.7275
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5595 - accuracy: 0.7266
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5581 - accuracy: 0.7279
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5581 - accuracy: 0.7294
# Epoch 10/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5573 - accuracy: 0.7287
# Epoch 10: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5574 - accuracy: 0.7285
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5566 - accuracy: 0.7296
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5565 - accuracy: 0.7286
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5561 - accuracy: 0.7295
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5560 - accuracy: 0.7292
# Epoch 15/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5548 - accuracy: 0.7308
# Epoch 15: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5549 - accuracy: 0.7305
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5555 - accuracy: 0.7299
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5547 - accuracy: 0.7295
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5546 - accuracy: 0.7311
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5543 - accuracy: 0.7303
# Epoch 20/100
# 788/804 [============================>.] - ETA: 0s - loss: 0.5536 - accuracy: 0.7317
# Epoch 20: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5541 - accuracy: 0.7308
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5540 - accuracy: 0.7318
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.7317
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7320
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7318
# Epoch 25/100
# 789/804 [============================>.] - ETA: 0s - loss: 0.5530 - accuracy: 0.7311
# Epoch 25: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5526 - accuracy: 0.7315
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5528 - accuracy: 0.7318
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5528 - accuracy: 0.7318
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7324
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5522 - accuracy: 0.7324
# Epoch 30/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5526 - accuracy: 0.7327
# Epoch 30: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7327
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7317
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7326
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7324
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5521 - accuracy: 0.7325
# Epoch 35/100
# 789/804 [============================>.] - ETA: 0s - loss: 0.5511 - accuracy: 0.7334
# Epoch 35: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7327
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7327
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7329
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7330
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7334
# Epoch 40/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5511 - accuracy: 0.7336
# Epoch 40: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7331
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7331
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7333
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7325
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7329
# Epoch 45/100
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5502 - accuracy: 0.7336
# Epoch 45: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7335
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7330
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7326
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7329
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7329
# Epoch 50/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5496 - accuracy: 0.7335
# Epoch 50: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7334
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7334
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7329
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7339
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7338
# Epoch 55/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5500 - accuracy: 0.7335
# Epoch 55: saving model to checkpoints/weights.55.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5496 - accuracy: 0.7339
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5493 - accuracy: 0.7336
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7336
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7336
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5493 - accuracy: 0.7345
# Epoch 60/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5493 - accuracy: 0.7335
# Epoch 60: saving model to checkpoints/weights.60.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7335
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7329
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5491 - accuracy: 0.7341
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5490 - accuracy: 0.7339
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7341
# Epoch 65/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5488 - accuracy: 0.7346
# Epoch 65: saving model to checkpoints/weights.65.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7346
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.7347
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7349
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7356
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7339
# Epoch 70/100
# 792/804 [============================>.] - ETA: 0s - loss: 0.5485 - accuracy: 0.7352
# Epoch 70: saving model to checkpoints/weights.70.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.7352
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5486 - accuracy: 0.7344
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7347
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5493 - accuracy: 0.7346
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7356
# Epoch 75/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5486 - accuracy: 0.7344
# Epoch 75: saving model to checkpoints/weights.75.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.7345
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7335
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7348
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7339
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7343
# Epoch 80/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.5484 - accuracy: 0.7351
# Epoch 80: saving model to checkpoints/weights.80.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7351
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7346
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5486 - accuracy: 0.7339
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7352
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5486 - accuracy: 0.7347
# Epoch 85/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.5489 - accuracy: 0.7344
# Epoch 85: saving model to checkpoints/weights.85.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.7348
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7351
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7349
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7353
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7354
# Epoch 90/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5475 - accuracy: 0.7357
# Epoch 90: saving model to checkpoints/weights.90.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7352
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7353
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7355
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7351
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5474 - accuracy: 0.7355
# Epoch 95/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5474 - accuracy: 0.7360
# Epoch 95: saving model to checkpoints/weights.95.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7359
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7355
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7357
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7348
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7356
# Epoch 100/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5482 - accuracy: 0.7357
# Epoch 100: saving model to checkpoints/weights.100.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7356

# %% [markdown]
# Accuracy and Loss for the first model

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5567 - accuracy: 0.7284 - 440ms/epoch - 2ms/step
# Loss: 0.5566812753677368, Accuracy: 0.728396475315094

# %%
# Export model to HDF5 file
nn.save('AlphabetSoupCharity_Optimization03.h5')
